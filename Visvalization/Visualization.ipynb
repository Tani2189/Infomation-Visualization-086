# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Attendance.csv")

# %%
df=df.dropna()

# %%
df.head()
# Out:
#   Course Code                        Course Title Category  \
# 0   18CSC302J                   Computer Networks   Theory
# 2   18CSE412J                  Offensive Security   Theory
# 4   18MAB302T  Discrete Mathematics for Engineers   Theory
# 6   18LEM109T        Indian Traditional Knowledge   Theory
# 8   18CSE301J           Information Visualization   Theory
#
#                   Faculty Name Slot  Hours Conducted  Hours Absent  Attn %
# 0  Dr.C.Vijayakumaran (102205)    A             18.0           3.0   83.33
# 2     Ms.Ida Seraphim (101562)    B             15.0           0.0  100.00
# 4      Dr Rupak Dutta (103074)    C             20.0           7.0   65.00
# 6  Dr.C.Vijayakumaran (102205)    D              7.0           0.0  100.00
# 8      Dr.N.Parthiban (102452)    D              0.0           0.0    0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Course Code      26 non-null     object
#  1   Course Title     13 non-null     object
#  2   Category         13 non-null     object
#  3   Faculty Name     13 non-null     object
#  4   Slot             13 non-null     object
#  5   Hours Conducted  13 non-null     float64
#  6   Hours Absent     13 non-null     float64
#  7   Attn %           13 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# Course Code        0
# Course Title       0
# Category           0
# Faculty Name       0
# Slot               0
# Hours Conducted    0
# Hours Absent       0
# Attn %             0
# dtype: int64

# %%
plt.figure(figsize=(20,20))
df.plot(kind="bar",x="Course Code",y="Attn %",color="pink")
# Out:
# <AxesSubplot: xlabel='Course Code'>

# %%
df.plot(kind="bar",x="Attn %")
# Out:
# <AxesSubplot: xlabel='Attn %'>

# %%
df.groupby(['Course Code']).sum().plot(kind="pie",y="Hours Conducted",autopct='%1.0f%%',legend=False)
# Out:
# C:\Users\Tanishq\AppData\Local\Temp\ipykernel_8732\487758624.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Course Code']).sum().plot(kind="pie",y="Hours Conducted",autopct='%1.0f%%',legend=False)
# <AxesSubplot: ylabel='Hours Conducted'>
